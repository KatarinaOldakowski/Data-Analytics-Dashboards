# %%
# Tableau Dashboard for HR Dataset

# %%
# https://public.tableau.com/app/profile/kat.oldakowski/viz/Project1_16884214567320/HRDashboard

# %% [markdown]
# ![Screenshot%202023-07-31%20201855.jpg](attachment:Screenshot%202023-07-31%20201855.jpg)
